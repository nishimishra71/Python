# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from tensorflow.keras.datasets import cifar10

X= pickle.load(open("X.pickle","rb"))
y= pickle.load(open("y.pickle","rb"))

from tensorflow.keras.datasets import cifar10

X=X/255.0


model=Sequential()
model.add(Conv2D(256,(3,3),input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model=Sequential()
model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))# added additional activation function as compared to the previous model

import numpy as np

model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

#https://www.youtube.com/watch?v=WvoLTXIjBYU&list=PLQVvvaa0QuDfhTox0AjmQ6tvTgMBZBEXN&index=3

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
NAME = "Cats-vs-dogs-CNN"
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

# %%
model.fit(X, np.uint8(y), batch_size=32, epochs=10, validation_split=0.3,callbacks=[tensorboard])
# Out:
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 48s 3ms/sample - loss: 0.6228 - accuracy: 0.6563 - val_loss: 0.5873 - val_accuracy: 0.6851
# Epoch 2/10
# 17462/17462 [==============================] - 47s 3ms/sample - loss: 0.5358 - accuracy: 0.7358 - val_loss: 0.5627 - val_accuracy: 0.7126
# Epoch 3/10
# 17462/17462 [==============================] - 44s 3ms/sample - loss: 0.4922 - accuracy: 0.7630 - val_loss: 0.5261 - val_accuracy: 0.7401
# Epoch 4/10
# 17462/17462 [==============================] - 53s 3ms/sample - loss: 0.4529 - accuracy: 0.7886 - val_loss: 0.5351 - val_accuracy: 0.7416
# Epoch 5/10
# 17462/17462 [==============================] - 52s 3ms/sample - loss: 0.4173 - accuracy: 0.8068 - val_loss: 0.5456 - val_accuracy: 0.7338
# Epoch 6/10
# 17462/17462 [==============================] - 51s 3ms/sample - loss: 0.3719 - accuracy: 0.8360 - val_loss: 0.6189 - val_accuracy: 0.7229
# Epoch 7/10
# ...

# %%
# !pip install --upgrade setuptools #uograded setuptools to ver 41.6 as previous one was not working
# Out:
# ...
#     100% |████████████████████████████████| 583kB 3.5MB/s ta 0:00:011
# ...
#   Found existing installation: setuptools 40.8.0
#     Uninstalling setuptools-40.8.0:
#       Successfully uninstalled setuptools-40.8.0
# ...

# %% [markdown]
# ### After having run this, you should have a new directory called logs. We can visualize the initial results from this directory using tensorboard now. Open a console, change to your working directory, and type: tensorboard --logdir=logs/. You should see a notice like: TensorBoard 1.10.0 at http://localhost:60076 (Press CTRL+C to quit)  Open a browser and head to this address.

# %% [markdown]
# ![cat_dog.png](attachment:cat_dog.png)
#
# This is the observed graph
